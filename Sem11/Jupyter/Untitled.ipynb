# %%
import sympy.polys.polytools
from sympy import *
from sympy.plotting import plot
init_printing()

# %%
x = Symbol('x')
f1 = x ** 3 - 50 * x
f2 = -x ** 4 + 88 * x ** 2 - 241

# %%
poly1 = sympy.polys.polytools.poly_from_expr(str(f1))[0]
poly2 = sympy.polys.polytools.poly_from_expr(str(f2))[0]
poly_sum = (poly1 + poly2).as_expr()
print(poly_sum)
# Out:
# -x**4 + x**3 + 88*x**2 - 50*x - 241

# %%
lst = solve(poly_sum, x)
for i in lst:
    print(i, end=2*'\n')
# Out:
# 1/4 - sqrt(707/12 + 5393/(9*(198439/432 + sqrt(61480244863)*I/48)**(1/3)) + 2*(198439/432 + sqrt(61480244863)*I/48)**(1/3))/2 - sqrt(707/6 - 2*(198439/432 + sqrt(61480244863)*I/48)**(1/3) + 47/(4*sqrt(707/12 + 5393/(9*(198439/432 + sqrt(61480244863)*I/48)**(1/3)) + 2*(198439/432 + sqrt(61480244863)*I/48)**(1/3))) - 5393/(9*(198439/432 + sqrt(61480244863)*I/48)**(1/3)))/2
#
# 1/4 + sqrt(707/12 + 5393/(9*(198439/432 + sqrt(61480244863)*I/48)**(1/3)) + 2*(198439/432 + sqrt(61480244863)*I/48)**(1/3))/2 - sqrt(707/6 - 2*(198439/432 + sqrt(61480244863)*I/48)**(1/3) - 47/(4*sqrt(707/12 + 5393/(9*(198439/432 + sqrt(61480244863)*I/48)**(1/3)) + 2*(198439/432 + sqrt(61480244863)*I/48)**(1/3))) - 5393/(9*(198439/432 + sqrt(61480244863)*I/48)**(1/3)))/2
#
# ...

# %%
pfun1 = plot(f1, line_color='red', title='f1 and f2', show=False)
pfun2 = plot(f2, line_color='blue', show=False)
pfun1.append(pfun2[0])
pfun1.show()

# %%
pfun3 = plot(poly_sum, line_color='green', title='general function')
print(poly_sum)
# Out:
# -x**4 + x**3 + 88*x**2 - 50*x - 241
